# %% [markdown]
# # Matplotlib基础绘图函数示例

# %% [markdown]
# ## 概述

# %% [markdown]
# 建议使用面向对象的方法绘制

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 一：pyplot饼图的绘制

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# axis('equal')用来绘制正圆形图像

# %% [markdown]
# ## 二：pyplot直方图的绘制

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 三：pyplot极坐标的绘制

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 使用了面向对象绘制图像

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 四：pyplot散点图的绘制

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 总结

# %% [markdown]
# ![image.png](attachment:image.png)
